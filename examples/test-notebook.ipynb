# %%
R.version
# Out:
#                _
# platform       x86_64-conda-linux-gnu
# arch           x86_64
# os             linux-gnu
# system         x86_64, linux-gnu
# status
# major          4
# minor          4.3
# year           2025
# month          02
# day            28
# svn rev        87843
# language       R
# version.string R version 4.4.3 (2025-02-28)
# nickname       Trophy Case

# %%
# Create a dummy bar plot
barplot(c(1, 2, 3), names.arg = c("A", "B", "C"), col = "blue")
# Create a dummy scatter plot
plot(c(1, 2, 3), c(4, 5, 6), col = "red", pch = 16)
# Out:
# plot without title
# plot without title
